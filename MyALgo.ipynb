# %% [markdown]
# <a href="https://colab.research.google.com/github/mathengem/Algorithmic-Trading-Backtesting-in-python/blob/main/MyALgo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yahoo_fin
# !pip install alpaca_trade_api
# !pip install yfinance
# !pip install pandas_ta
# Out:
# Collecting yahoo_fin
#   Downloading yahoo_fin-0.8.9.1-py3-none-any.whl (10 kB)
# Collecting requests-html (from yahoo_fin)
#   Downloading requests_html-0.10.0-py3-none-any.whl (13 kB)
# Collecting feedparser (from yahoo_fin)
#   Downloading feedparser-6.0.11-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from yahoo_fin) (2.31.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from yahoo_fin) (2.0.3)
# Collecting sgmllib3k (from feedparser->yahoo_fin)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->yahoo_fin) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->yahoo_fin) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->yahoo_fin) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->yahoo_fin) (1.25.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->yahoo_fin) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->yahoo_fin) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->yahoo_fin) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->yahoo_fin) (2024.6.2)
# Collecting pyquery (from requests-html->yahoo_fin)
#   Downloading pyquery-2.0.0-py3-none-any.whl (22 kB)
# Collecting fake-useragent (from requests-html->yahoo_fin)
#   Downloading fake_useragent-1.5.1-py3-none-any.whl (17 kB)
# Collecting parse (from requests-html->yahoo_fin)
#   Downloading parse-1.20.2-py2.py3-none-any.whl (20 kB)
# Collecting bs4 (from requests-html->yahoo_fin)
#   Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Collecting w3lib (from requests-html->yahoo_fin)
#   Downloading w3lib-2.2.1-py3-none-any.whl (21 kB)
# Collecting pyppeteer>=0.0.14 (from requests-html->yahoo_fin)
#   Downloading pyppeteer-2.0.0-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.9/82.9 kB 5.3 MB/s eta 0:00:00
# Collecting appdirs<2.0.0,>=1.4.3 (from pyppeteer>=0.0.14->requests-html->yahoo_fin)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (7.2.0)
# Collecting pyee<12.0.0,>=11.0.0 (from pyppeteer>=0.0.14->requests-html->yahoo_fin)
#   Downloading pyee-11.1.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.66.4)
# Collecting urllib3<3,>=1.21.1 (from requests->yahoo_fin)
#   Downloading urllib3-1.26.19-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.9/143.9 kB 6.0 MB/s eta 0:00:00
# Collecting websockets<11.0,>=10.0 (from pyppeteer>=0.0.14->requests-html->yahoo_fin)
#   Downloading websockets-10.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->yahoo_fin) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4->requests-html->yahoo_fin) (4.12.3)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.10/dist-packages (from pyquery->requests-html->yahoo_fin) (4.9.4)
# Collecting cssselect>=1.2.0 (from pyquery->requests-html->yahoo_fin)
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (3.19.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pyee<12.0.0,>=11.0.0->pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4->requests-html->yahoo_fin) (2.5)
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6049 sha256=a90394472316ad52dd2a6cc0ffa280e41079e3e4c54b762d46b215bec94fe229
#   Stored in directory: /root/.cache/pip/wheels/f0/69/93/a47e9d621be168e9e33c7ce60524393c0b92ae83cf6c6e89c5
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, parse, fake-useragent, appdirs, websockets, w3lib, urllib3, pyee, feedparser, cssselect, pyquery, pyppeteer, bs4, requests-html, yahoo_fin
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
# Successfully installed appdirs-1.4.4 bs4-0.0.2 cssselect-1.2.0 fake-useragent-1.5.1 feedparser-6.0.11 parse-1.20.2 pyee-11.1.0 pyppeteer-2.0.0 pyquery-2.0.0 requests-html-0.10.0 sgmllib3k-1.0.0 urllib3-1.26.19 w3lib-2.2.1 websockets-10.4 yahoo_fin-0.8.9.1
# Collecting alpaca_trade_api
#   Downloading alpaca_trade_api-3.2.0-py3-none-any.whl (34 kB)
# Requirement already satisfied: pandas>=0.18.1 in /usr/local/lib/python3.10/dist-packages (from alpaca_trade_api) (2.0.3)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.10/dist-packages (from alpaca_trade_api) (1.25.2)
# Requirement already satisfied: requests<3,>2 in /usr/local/lib/python3.10/dist-packages (from alpaca_trade_api) (2.31.0)
# Requirement already satisfied: urllib3<2,>1.24 in /usr/local/lib/python3.10/dist-packages (from alpaca_trade_api) (1.26.19)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /usr/local/lib/python3.10/dist-packages (from alpaca_trade_api) (1.8.0)
# Requirement already satisfied: websockets<11,>=9.0 in /usr/local/lib/python3.10/dist-packages (from alpaca_trade_api) (10.4)
# Collecting msgpack==1.0.3 (from alpaca_trade_api)
#   Downloading msgpack-1.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (323 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.7/323.7 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp<4,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from alpaca_trade_api) (3.9.5)
# Requirement already satisfied: PyYAML==6.0.1 in /usr/local/lib/python3.10/dist-packages (from alpaca_trade_api) (6.0.1)
# Collecting deprecation==2.1.0 (from alpaca_trade_api)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from deprecation==2.1.0->alpaca_trade_api) (24.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.8.3->alpaca_trade_api) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.8.3->alpaca_trade_api) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.8.3->alpaca_trade_api) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.8.3->alpaca_trade_api) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.8.3->alpaca_trade_api) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.8.3->alpaca_trade_api) (4.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.18.1->alpaca_trade_api) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.18.1->alpaca_trade_api) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.18.1->alpaca_trade_api) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>2->alpaca_trade_api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>2->alpaca_trade_api) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>2->alpaca_trade_api) (2024.6.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.18.1->alpaca_trade_api) (1.16.0)
# Installing collected packages: msgpack, deprecation, alpaca_trade_api
#   Attempting uninstall: msgpack
#     Found existing installation: msgpack 1.0.8
#     Uninstalling msgpack-1.0.8:
#       Successfully uninstalled msgpack-1.0.8
# Successfully installed alpaca_trade_api-3.2.0 deprecation-2.1.0 msgpack-1.0.3
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.40)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.0.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.25.2)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.9.4)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.2.2)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2023.4)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.5)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2024.6.2)
# Collecting pandas_ta
#   Downloading pandas_ta-0.3.14b.tar.gz (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.1/115.1 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pandas_ta) (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->pandas_ta) (1.16.0)
# Building wheels for collected packages: pandas_ta
#   Building wheel for pandas_ta (setup.py) ... done
#   Created wheel for pandas_ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=218907 sha256=c1c54fafacddb4fc2f326e497ac02487e7abd3704bef5ba32f7dcb7967f53692
#   Stored in directory: /root/.cache/pip/wheels/69/00/ac/f7fa862c34b0e2ef320175100c233377b4c558944f12474cf0
# Successfully built pandas_ta
# Installing collected packages: pandas_ta
# Successfully installed pandas_ta-0.3.14b0

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)

# %%
import numpy as np
import pandas as pd
import datetime as dt
import tensorflow as tf
from yahoo_fin import stock_info as yf
from sklearn.preprocessing import MinMaxScaler
from collections import deque
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
import matplotlib.pyplot as plt
import requests as rq
import alpaca_trade_api as api
import logging
import json
from multiprocessing import Process, Manager
import time

# Load configuration from a JSON file
with open('config.json') as config_file:
    config = json.load(config_file)

# SETTINGS
TRADER_BOT_NAME = config['TRADER_BOT_NAME']
TRADER_API_KEY = config['TRADER_API_KEY']
TRADER_API_SECRET = config['TRADER_API_SECRET']
TRADER_API_URL = config['TRADER_API_URL']
TELEGRAM_URL = config['TELEGRAM_URL']
TELEGRAM_BOT_ID = config['TELEGRAM_BOT_ID']
TELEGRAM_CHAT_ID = config['TELEGRAM_CHAT_ID']
SCREENER_INTERVAL = config['SCREENER_INTERVAL']
SCREENER_PERIOD = config['SCREENER_PERIOD']
SCREENER_NASDAQ_COUNT = config['SCREENER_NASDAQ_COUNT']
TAKE_PROFIT_DELTA = config['TAKE_PROFIT_DELTA']
CASH_LIMIT = config['CASH_LIMIT']

N_STEPS = 7
LOOKUP_STEPS = [1, 2, 3]
BATCH_SIZE = 8
EPOCHS = 80

# Set up logging
logging.basicConfig(filename='trading_bot.log', level=logging.INFO,
                    format='%(asctime)s - %(levelname)s - %(message)s')

# Performance tracking
performance = {
    'trades': 0,
    'successful_trades': 0,
    'failed_trades': 0,
    'total_profit_loss': 0
}

# Create a shared dictionary for predictions
manager = Manager()
shared_predictions = manager.dict()

def send_message(message):
    try:
        response = rq.post(
            f'{TELEGRAM_URL}/{TELEGRAM_BOT_ID}/sendMessage?chat_id={TELEGRAM_CHAT_ID}&parse_mode=Markdown&text={message}'
        )
        response.raise_for_status()
        return response
    except rq.RequestException as e:
        logging.error(f"Failed to send Telegram message: {str(e)}")
        return None

def get_stock_data(ticker, start_date, end_date):
    try:
        df = yf.get_data(ticker, start_date=start_date, end_date=end_date, interval='1d')
        df = df[['close']]
        df['date'] = df.index
        return df
    except Exception as e:
        logging.error(f"Error fetching data for {ticker}: {e}")
        return None

def prepare_data(df, days):
    scaler = MinMaxScaler()
    df['close'] = scaler.fit_transform(df[['close']])

    df['future'] = df['close'].shift(-days)
    last_sequence = np.array(df[['close']].tail(days))
    df.dropna(inplace=True)

    sequence_data = []
    sequences = deque(maxlen=N_STEPS)

    for entry, target in zip(df[['close', 'date']].values, df['future'].values):
        sequences.append(entry)
        if len(sequences) == N_STEPS:
            sequence_data.append([np.array(sequences), target])

    last_sequence = list([s[:1] for s in sequences]) + list(last_sequence)
    last_sequence = np.array(last_sequence).astype(np.float32)

    X, Y = [], []
    for seq, target in sequence_data:
        X.append(seq)
        Y.append(target)

    X = np.array(X)
    Y = np.array(Y)

    return df, last_sequence, X, Y, scaler

def create_model(input_shape):
    model = Sequential([
        LSTM(60, return_sequences=True, input_shape=input_shape),
        Dropout(0.3),
        LSTM(120, return_sequences=False),
        Dropout(0.3),
        Dense(20),
        Dense(1)
    ])
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

def train_model(model, X, Y):
    model.fit(X, Y, batch_size=BATCH_SIZE, epochs=EPOCHS, verbose=1)
    return model

def predict_prices(model, last_sequence, scaler):
    last_sequence = last_sequence[-N_STEPS:]
    last_sequence = np.expand_dims(last_sequence, axis=0)
    prediction = model.predict(last_sequence)
    predicted_price = scaler.inverse_transform(prediction)[0][0]
    return round(float(predicted_price), 2)

def run_predictions(shared_predictions):
    while True:
        for stock in ['GOOGL', 'AAPL', 'MSFT', 'AMZN', 'FB']:  # Add more stocks as needed
            end_date = dt.date.today().strftime('%Y-%m-%d')
            start_date = (dt.date.today() - dt.timedelta(days=1104)).strftime('%Y-%m-%d')

            df = get_stock_data(stock, start_date, end_date)
            if df is None:
                continue

            predictions = []
            for step in LOOKUP_STEPS:
                df_processed, last_sequence, X, Y, scaler = prepare_data(df.copy(), step)
                X = X[:, :, :1].astype(np.float32)

                model = create_model((N_STEPS, 1))
                model = train_model(model, X, Y)

                prediction = predict_prices(model, last_sequence, scaler)
                predictions.append(prediction)

            shared_predictions[stock] = predictions
            logging.info(f"Updated predictions for {stock}: {predictions}")

        time.sleep(3600)  # Wait for an hour before updating predictions again

def CheckStock(stock):
    data = {}
    try:
        df = yf.get_data(stock, period=SCREENER_PERIOD, interval=SCREENER_INTERVAL)
        if len(df) > 0:
            df['RSI'] = ta.rsi(df['Close'], timeperiod=14)
            bbands = ta.bbands(df['Close'], length=20, std=2.3)
            df['L'] = bbands['BBL_20_2.3']
            df['M'] = bbands['BBM_20_2.3']
            df['U'] = bbands['BBU_20_2.3']

            previous2_bar = df[-3:].head(1)
            previous_bar = df[-2:].head(1)
            current_bar = df[-1:]

            if current_bar['RSI'].values[0] > 70 and current_bar['Close'].values[0] > current_bar['U'].values[0]:
                data = {
                    'direction': 'DOWN',
                    'stock': stock,
                    'stop_loss': round(max(previous_bar['High'].values[0], previous2_bar['High'].values[0], previous_bar['U'].values[0]), 2),
                    'take_profit': round(min(previous_bar['Low'].values[0], previous2_bar['Low'].values[0], previous_bar['M'].values[0]), 2)
                }
            elif current_bar['RSI'].values[0] < 30 and current_bar['Close'].values[0] < current_bar['L'].values[0]:
                data = {
                    'direction': 'UP',
                    'stock': stock,
                    'stop_loss': round(min(previous_bar['Low'].values[0], previous2_bar['Low'].values[0], previous_bar['L'].values[0]), 2),
                    'take_profit': round(max(previous_bar['High'].values[0], previous2_bar['High'].values[0], previous_bar['M'].values[0]), 2)
                }
    except Exception as e:
        logging.error(f"Error checking stock {stock}: {str(e)}")
    return data

def ScreenStocks(trader_api):
    try:
        assets = trader_api.list_assets(status='active', asset_class='us_equity')
        assets = [x for x in assets if x.shortable == True and x.exchange == 'NASDAQ']
        stocks = [x.symbol for x in assets][:SCREENER_NASDAQ_COUNT]

        screened = []
        for st in stocks:
            _stock = CheckStock(st)
            if _stock != {}:
                screened.append(_stock)

        screened = [x for x in screened if abs(x['stop_loss'] - x['take_profit']) > min(x['stop_loss'], x['take_profit']) * TAKE_PROFIT_DELTA]
        return screened
    except Exception as e:
        logging.error(f"Error screening stocks: {str(e)}")
        return []

def Trade(api, stock, operation, shares_to_trade, take_profit, stop_loss):
    try:
        api.submit_order(
            symbol=stock,
            qty=shares_to_trade,
            side=operation,
            type='market',
            order_class='bracket',
            time_in_force='day',
            take_profit={'limit_price': take_profit},
            stop_loss={'stop_price': stop_loss}
        )
        message = f'\n\t*{stock}*, qty _{shares_to_trade}_ \n\t\twere {operation}'
        send_message(f'{TRADER_BOT_NAME}: we entered the market with:' + message)
        performance['trades'] += 1
        performance['successful_trades'] += 1
        return True
    except Exception as e:
        logging.error(f"Error executing trade for {stock}: {str(e)}")
        performance['trades'] += 1
        performance['failed_trades'] += 1
        return False

def medium_trader_go(shared_predictions):
    trader_api = api.REST(TRADER_API_KEY, TRADER_API_SECRET, TRADER_API_URL)

    while True:
        try:
            account = trader_api.get_account()
            clock = trader_api.get_clock()
        except Exception as e:
            logging.error(f"Error connecting to Alpaca API: {str(e)}")
            time.sleep(60)
            continue

        if bool(account) == True:
            message = f'''{TRADER_BOT_NAME}: for *{account.account_number}*
            current capital is _{account.portfolio_value}$_
            and non marginable buying power is _{account.non_marginable_buying_power}$_'''
            send_message(message)

        if clock.is_open == True:
            if float(account.non_marginable_buying_power) < CASH_LIMIT:
                message = f"{TRADER_BOT_NAME}: there is no cash on the account or limit reached!"
                send_message(message)
            else:
                screened = ScreenStocks(trader_api)
                if len(screened) > 0:
                    CASH_FOR_TRADE_PER_SHARE = (float(account.non_marginable_buying_power) - CASH_LIMIT) / len(screened)
                    for item in screened:
                        predictions = shared_predictions.get(item['stock'], [])
                        if predictions:
                            STOCK = item['stock']
                            OPERATION = 'buy' if item['direction'] == 'UP' else 'sell'
                            STOP_LOSS = min([item['stop_loss']] + predictions) if item['direction'] == 'UP' else max([item['stop_loss']] + predictions)
                            TAKE_PROFIT = max([item['take_profit']] + predictions) if item['direction'] == 'UP' else min([item['take_profit']] + predictions)
                            SHARE_PRICE = round(min(STOP_LOSS, TAKE_PROFIT), 2)
                            SHARES_TO_TRADE = int(CASH_FOR_TRADE_PER_SHARE / SHARE_PRICE)
                            if abs(STOP_LOSS - TAKE_PROFIT) > SHARE_PRICE * TAKE_PROFIT_DELTA and SHARES_TO_TRADE > 0:
                                Trade(trader_api, STOCK, OPERATION, SHARES_TO_TRADE, TAKE_PROFIT, STOP_LOSS)
                                logging.info(f'{STOCK}: {STOP_LOSS}, {TAKE_PROFIT}, {OPERATION}, {SHARES_TO_TRADE}')

        try:
            portfolio = trader_api.list_positions()
            if bool(portfolio) == True:
                message = f'{TRADER_BOT_NAME}: we have {len(portfolio)} opened positions.'
                total_pl = 0
                for i in portfolio:
                    message += f'\n\t*{i.symbol}*: qty {i.qty} {i.side} for _{i.market_value}$_ \n\t\t\tcurrent price _{i.current_price}$_ \n\t\t\tprofit _{i.unrealized_pl}$_'
                    total_pl += float(i.unrealized_pl)
                performance['total_profit_loss'] = total_pl
                send_message(message)
        except Exception as e:
            logging.error(f"Error fetching portfolio: {str(e)}")

        if clock.is_open == False:
            message = f"{TRADER_BOT_NAME}: the market is *CLOSED*, let's try later on!"
            send_message(message)

        # Log performance metrics
        logging.info(f"Performance metrics: {json.dumps(performance)}")

        time.sleep(300)  # Wait for 5 minutes before next iteration

if __name__ == "__main__":
    prediction_process = Process(target=run_predictions, args=(shared_predictions,))
    trading_process = Process(target=medium_trader_go, args=(shared_predictions,))

    prediction_process.start()
    trading_process.start()

    prediction_process.join()
    trading_process.join()
# Out:
# Epoch 1/80
# 94/94 [==============================] - 6s 11ms/step - loss: 0.0161
# Epoch 2/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0044
# Epoch 3/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0032
# Epoch 4/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0035
# Epoch 5/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0030
# Epoch 6/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0028
# Epoch 7/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0026
# Epoch 8/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0027
# Epoch 9/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0023
# Epoch 10/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0024
# Epoch 11/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0022
# Epoch 12/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0021
# Epoch 13/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0020
# Epoch 14/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 15/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0019
# Epoch 16/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0019
# Epoch 17/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0018
# Epoch 18/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0017
# Epoch 19/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0016
# Epoch 20/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0018
# Epoch 21/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0016
# Epoch 22/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0016
# Epoch 23/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0016
# Epoch 24/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0015
# Epoch 25/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0016
# Epoch 26/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 27/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0015
# Epoch 28/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0015
# Epoch 29/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0015
# Epoch 30/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0014
# Epoch 31/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0016
# Epoch 32/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0014
# Epoch 33/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0014
# Epoch 34/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0014
# Epoch 35/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 36/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0015
# Epoch 37/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 38/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0015
# Epoch 39/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 40/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 41/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0015
# Epoch 42/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0015
# Epoch 43/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 44/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 45/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0016
# Epoch 46/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 47/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0015
# Epoch 48/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0014
# Epoch 49/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 50/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0013
# Epoch 51/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0012
# Epoch 52/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 53/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0016
# Epoch 54/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0014
# Epoch 55/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0014
# Epoch 56/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0013
# Epoch 57/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0014
# Epoch 58/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0013
# Epoch 59/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 60/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 61/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 62/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0012
# Epoch 63/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 64/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 65/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0012
# Epoch 66/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 67/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 68/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0015
# Epoch 69/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0011
# Epoch 70/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0012
# Epoch 71/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 72/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0012
# Epoch 73/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0015
# Epoch 74/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0013
# Epoch 75/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011
# Epoch 76/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0012
# Epoch 77/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0012
# Epoch 78/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0013
# Epoch 79/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012
# Epoch 80/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0014
# 1/1 [==============================] - 1s 829ms/step
# Epoch 1/80
# 94/94 [==============================] - 5s 10ms/step - loss: 0.0150
# Epoch 2/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0042
# Epoch 3/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0039
# Epoch 4/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0038
# Epoch 5/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0036
# Epoch 6/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0031
# Epoch 7/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0032
# Epoch 8/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0029
# Epoch 9/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0028
# Epoch 10/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0027
# Epoch 11/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0028
# Epoch 12/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0025
# Epoch 13/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0024
# Epoch 14/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0028
# Epoch 15/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0023
# Epoch 16/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0024
# Epoch 17/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0025
# Epoch 18/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0025
# Epoch 19/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0025
# Epoch 20/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0023
# Epoch 21/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0023
# Epoch 22/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0022
# Epoch 23/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0024
# Epoch 24/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0021
# Epoch 25/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0022
# Epoch 26/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0021
# Epoch 27/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0020
# Epoch 28/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0023
# Epoch 29/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0021
# Epoch 30/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0020
# Epoch 31/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0022
# Epoch 32/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0023
# Epoch 33/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0021
# Epoch 34/80
# 94/94 [==============================] - ETA: 0s - loss: 0.0021Epoch 35/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0021
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0022
# Epoch 36/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0021
# Epoch 37/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0021
# Epoch 38/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0020
# Epoch 39/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0021
# Epoch 40/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0019
# Epoch 41/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0021
# Epoch 42/80
# 94/94 [==============================] - 2s 19ms/step - loss: 0.0019
# Epoch 43/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0020
# Epoch 44/80
# 94/94 [==============================] - 2s 19ms/step - loss: 0.0020
# Epoch 45/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0020
# Epoch 46/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0020
# Epoch 47/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0020
# Epoch 48/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0021
# Epoch 49/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 50/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0020
# Epoch 51/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0020
# Epoch 52/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0018
# Epoch 53/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0020
# Epoch 54/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0021
# Epoch 55/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0020
# Epoch 56/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0020
# Epoch 57/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0019
# Epoch 58/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0020
# Epoch 59/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0022
# Epoch 60/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0019
# Epoch 61/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0020
# Epoch 62/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0019
# Epoch 63/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0019
# Epoch 64/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0018
# Epoch 65/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0020
# Epoch 66/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0019
# Epoch 67/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0019
# Epoch 68/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0020
# Epoch 69/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0021
# Epoch 70/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0019
# Epoch 71/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0019
# Epoch 72/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0019
# Epoch 73/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0020
# Epoch 74/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0019
# Epoch 75/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0020
# Epoch 76/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0017
# Epoch 77/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0018
# Epoch 78/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0021
# Epoch 79/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0020
# Epoch 80/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0018
# 1/1 [==============================] - 1s 1s/step
# Epoch 1/80
# 94/94 [==============================] - 5s 11ms/step - loss: 0.0163
# Epoch 2/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0062
# Epoch 3/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0042
# Epoch 4/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0041
# Epoch 5/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0036
# Epoch 6/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0036
# Epoch 7/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0033
# Epoch 8/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0035
# Epoch 9/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0033
# Epoch 10/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0036
# Epoch 11/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0031
# Epoch 12/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0034
# Epoch 13/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0029
# Epoch 14/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0031
# Epoch 15/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0030
# Epoch 16/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0028
# Epoch 17/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0031
# Epoch 18/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0029
# Epoch 19/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0029
# Epoch 20/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0028
# Epoch 21/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0027
# Epoch 22/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0026
# Epoch 23/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0027
# Epoch 24/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0027
# Epoch 25/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0025
# Epoch 26/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0026
# Epoch 27/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0027
# Epoch 28/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0028
# Epoch 29/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0026
# Epoch 30/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0026
# Epoch 31/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0025
# Epoch 32/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0026
# Epoch 33/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0028
# Epoch 34/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0025
# Epoch 35/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0024
# Epoch 36/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0026
# Epoch 37/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0027
# Epoch 38/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0025
# Epoch 39/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0029
# Epoch 40/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0025
# Epoch 41/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0028
# Epoch 42/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0025
# Epoch 43/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0025
# Epoch 44/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0027
# Epoch 45/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0026
# Epoch 46/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0025
# Epoch 47/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0024
# Epoch 48/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0027
# Epoch 49/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0025
# Epoch 50/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0025
# Epoch 51/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0028
# Epoch 52/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0025
# Epoch 53/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0024
# Epoch 54/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0024
# Epoch 55/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0026
# Epoch 56/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0024
# Epoch 57/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0026
# Epoch 58/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0023
# Epoch 59/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0024
# Epoch 60/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0027
# Epoch 61/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0026
# Epoch 62/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0023
# Epoch 63/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0024
# Epoch 64/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0026
# Epoch 65/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0023
# Epoch 66/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0024
# Epoch 67/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0024
# Epoch 68/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0024
# Epoch 69/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0027
# Epoch 70/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0025
# Epoch 71/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0026
# Epoch 72/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0026
# Epoch 73/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0027
# Epoch 74/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0024
# Epoch 75/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0022
# Epoch 76/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0023
# Epoch 77/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0024
# Epoch 78/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0024
# Epoch 79/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0024
# Epoch 80/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0026
# 1/1 [==============================] - 1s 762ms/step
# Epoch 1/80
# 94/94 [==============================] - 5s 14ms/step - loss: 0.0158
# Epoch 2/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0052
# Epoch 3/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0045
# Epoch 4/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0041
# Epoch 5/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0042
# Epoch 6/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0034
# Epoch 7/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0033
# Epoch 8/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0037
# Epoch 9/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0030
# Epoch 10/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0028
# Epoch 11/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0026
# Epoch 12/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0025
# Epoch 13/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0026
# Epoch 14/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0024
# Epoch 15/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0022
# Epoch 16/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0023
# Epoch 17/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 18/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0022
# Epoch 19/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0022
# Epoch 20/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 21/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0020
# Epoch 22/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0020
# Epoch 23/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0020
# Epoch 24/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0017
# Epoch 25/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0019
# Epoch 26/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0017
# Epoch 27/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0018
# Epoch 28/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0019
# Epoch 29/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0018
# Epoch 30/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0016
# Epoch 31/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0018
# Epoch 32/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 33/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0020
# Epoch 34/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0019
# Epoch 35/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0017
# Epoch 36/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0018
# Epoch 37/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0019
# Epoch 38/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0018
# Epoch 39/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0017
# Epoch 40/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0018
# Epoch 41/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 42/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0016
# Epoch 43/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0017
# Epoch 44/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0016
# Epoch 45/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0016
# Epoch 46/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0016
# Epoch 47/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0016
# Epoch 48/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0016
# Epoch 49/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0017
# Epoch 50/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0017
# Epoch 51/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0015
# Epoch 52/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0015
# Epoch 53/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0016
# Epoch 54/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0016
# Epoch 55/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0016
# Epoch 56/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0016
# Epoch 57/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0016
# Epoch 58/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0016
# Epoch 59/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0016
# Epoch 60/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0015
# Epoch 61/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0016
# Epoch 62/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0017
# Epoch 63/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0016
# Epoch 64/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0015
# Epoch 65/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 66/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0017
# Epoch 67/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0016
# Epoch 68/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0016
# Epoch 69/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0015
# Epoch 70/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0015
# Epoch 71/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0016
# Epoch 72/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0016
# Epoch 73/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0015
# Epoch 74/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0014
# Epoch 75/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0017
# Epoch 76/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 77/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0015
# Epoch 78/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0017
# Epoch 79/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0015
# Epoch 80/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0016
# 1/1 [==============================] - 1s 1s/step
# Epoch 1/80
# 94/94 [==============================] - 7s 10ms/step - loss: 0.0177
# Epoch 2/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0063
# Epoch 3/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0061
# Epoch 4/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0057
# Epoch 5/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0043
# Epoch 6/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0045
# Epoch 7/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0047
# Epoch 8/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0041
# Epoch 9/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0040
# Epoch 10/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0037
# Epoch 11/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0036
# Epoch 12/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0035
# Epoch 13/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0034
# Epoch 14/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0032
# Epoch 15/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0037
# Epoch 16/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0034
# Epoch 17/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0032
# Epoch 18/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0033
# Epoch 19/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0029
# Epoch 20/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0031
# Epoch 21/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0030
# Epoch 22/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0030
# Epoch 23/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0030
# Epoch 24/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0032
# Epoch 25/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0031
# Epoch 26/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0032
# Epoch 27/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0026
# Epoch 28/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0030
# Epoch 29/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0028
# Epoch 30/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0026
# Epoch 31/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0027
# Epoch 32/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0027
# Epoch 33/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0029
# Epoch 34/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0029
# Epoch 35/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0029
# Epoch 36/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0029
# Epoch 37/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0028
# Epoch 38/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0028
# Epoch 39/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0029
# Epoch 40/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0032
# Epoch 41/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0028
# Epoch 42/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0030
# Epoch 43/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0026
# Epoch 44/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0028
# Epoch 45/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0028
# Epoch 46/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0027
# Epoch 47/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0026
# Epoch 48/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0029
# Epoch 49/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0027
# Epoch 50/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0029
# Epoch 51/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0028
# Epoch 52/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0026
# Epoch 53/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0028
# Epoch 54/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0027
# Epoch 55/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0027
# Epoch 56/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0026
# Epoch 57/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0027
# Epoch 58/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0028
# Epoch 59/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0024
# Epoch 60/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0025
# Epoch 61/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0027
# Epoch 62/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0026
# Epoch 63/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0027
# Epoch 64/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0029
# Epoch 65/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0026
# Epoch 66/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0028
# Epoch 67/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0027
# Epoch 68/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0026
# Epoch 69/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0024
# Epoch 70/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0026
# Epoch 71/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0030
# Epoch 72/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0027
# Epoch 73/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0026
# Epoch 74/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0027
# Epoch 75/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0027
# Epoch 76/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0024
# Epoch 77/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0026
# Epoch 78/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0025
# Epoch 79/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0027
# Epoch 80/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0027
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7e8c0afa5240> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 815ms/step
# Epoch 1/80
# 94/94 [==============================] - 7s 16ms/step - loss: 0.0203
# Epoch 2/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0074
# Epoch 3/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0061
# Epoch 4/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0065
# Epoch 5/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0059
# Epoch 6/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0062
# Epoch 7/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0067
# Epoch 8/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0048
# Epoch 9/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0049
# Epoch 10/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0046
# Epoch 11/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0046
# Epoch 12/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0043
# Epoch 13/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0041
# Epoch 14/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0042
# Epoch 15/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0042
# Epoch 16/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0041
# Epoch 17/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0040
# Epoch 18/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0039
# Epoch 19/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0043
# Epoch 20/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0039
# Epoch 21/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0039
# Epoch 22/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0038
# Epoch 23/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0037
# Epoch 24/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0038
# Epoch 25/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0039
# Epoch 26/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0042
# Epoch 27/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0038
# Epoch 28/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0038
# Epoch 29/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0042
# Epoch 30/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0039
# Epoch 31/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0037
# Epoch 32/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0036
# Epoch 33/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0037
# Epoch 34/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0037
# Epoch 35/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0037
# Epoch 36/80
# 94/94 [==============================] - 2s 19ms/step - loss: 0.0038
# Epoch 37/80
# 94/94 [==============================] - 2s 19ms/step - loss: 0.0035
# Epoch 38/80
# 94/94 [==============================] - 2s 19ms/step - loss: 0.0038
# Epoch 39/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0039
# Epoch 40/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0036
# Epoch 41/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0039
# Epoch 42/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0033
# Epoch 43/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0035
# Epoch 44/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0036
# Epoch 45/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0035
# Epoch 46/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0038
# Epoch 47/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0035
# Epoch 48/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0037
# Epoch 49/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0037
# Epoch 50/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0037
# Epoch 51/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0040
# Epoch 52/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0037
# Epoch 53/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0036
# Epoch 54/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0036
# Epoch 55/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0035
# Epoch 56/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0035
# Epoch 57/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0037
# Epoch 58/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0035
# Epoch 59/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0036
# Epoch 60/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0036
# Epoch 61/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0036
# Epoch 62/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0034
# Epoch 63/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0034
# Epoch 64/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0037
# Epoch 65/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0036
# Epoch 66/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0036
# Epoch 67/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0037
# Epoch 68/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0036
# Epoch 69/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0034
# Epoch 70/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0034
# Epoch 71/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0035
# Epoch 72/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0035
# Epoch 73/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0036
# Epoch 74/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0034
# Epoch 75/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0034
# Epoch 76/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0035
# Epoch 77/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0035
# Epoch 78/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0035
# Epoch 79/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0037
# Epoch 80/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0037
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7e8c07fc37f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 746ms/step
# Epoch 1/80
# 94/94 [==============================] - 4s 8ms/step - loss: 0.0162
# Epoch 2/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0036
# Epoch 3/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0031
# Epoch 4/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0026
# Epoch 5/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0029
# Epoch 6/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0029
# Epoch 7/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0029
# Epoch 8/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0023
# Epoch 9/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0024
# Epoch 10/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0022
# Epoch 11/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0023
# Epoch 12/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0018
# Epoch 13/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0016
# Epoch 14/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0019
# Epoch 15/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0018
# Epoch 16/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0016
# Epoch 17/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0015
# Epoch 18/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0016
# Epoch 19/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0017
# Epoch 20/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0016
# Epoch 21/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0017
# Epoch 22/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0016
# Epoch 23/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0015
# Epoch 24/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 25/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0017
# Epoch 26/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0017
# Epoch 27/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0014
# Epoch 28/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0016
# Epoch 29/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0014
# Epoch 30/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0014
# Epoch 31/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0016
# Epoch 32/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0015
# Epoch 33/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0015
# Epoch 34/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0015
# Epoch 35/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 36/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0015
# Epoch 37/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 38/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0016
# Epoch 39/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 40/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0013
# Epoch 41/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 42/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 43/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0014
# Epoch 44/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0013
# Epoch 45/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0015
# Epoch 46/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 47/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0013
# Epoch 48/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0015
# Epoch 49/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0016
# Epoch 50/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0015
# Epoch 51/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0012
# Epoch 52/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 53/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 54/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0012
# Epoch 55/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0011
# Epoch 56/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0012
# Epoch 57/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0020
# Epoch 58/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 59/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0012
# Epoch 60/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0011
# Epoch 61/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0012
# Epoch 62/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0012
# Epoch 63/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 64/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0013
# Epoch 65/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0012
# Epoch 66/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0014
# Epoch 67/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0013
# Epoch 68/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 69/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0012
# Epoch 70/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0012
# Epoch 71/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0013
# Epoch 72/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012
# Epoch 73/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 74/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0013
# Epoch 75/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 76/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0012
# Epoch 77/80
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0014
# Epoch 78/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 79/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0012
# Epoch 80/80
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0014
# 1/1 [==============================] - 1s 777ms/step
# Epoch 1/80
# 94/94 [==============================] - 7s 18ms/step - loss: 0.0139
# Epoch 2/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0042
# Epoch 3/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0034
# Epoch 4/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0035
# Epoch 5/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0033
# Epoch 6/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0032
# Epoch 7/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0027
# Epoch 8/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0025
# Epoch 9/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0025
# Epoch 10/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0027
# Epoch 11/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0029
# Epoch 12/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0025
# Epoch 13/80
# ...
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0020
# Epoch 48/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0020
# Epoch 49/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0020
# Epoch 50/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0021
# Epoch 51/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0018
# Epoch 52/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0018
# Epoch 53/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0021
# Epoch 54/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0020
# Epoch 55/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0020
# Epoch 56/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 57/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0020
# Epoch 58/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 59/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0021
# Epoch 60/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0019
# Epoch 61/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0020
# Epoch 62/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0022
# Epoch 63/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0017
# Epoch 64/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0020
# Epoch 65/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0020
# Epoch 66/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0020
# Epoch 67/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0018
# Epoch 68/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0018
# Epoch 69/80
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0018
# Epoch 70/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 71/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 72/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0018
# Epoch 73/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0018
# Epoch 74/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0019
# Epoch 75/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 76/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 77/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0017
# Epoch 78/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 79/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0019
# Epoch 80/80
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0022
# 1/1 [==============================] - 1s 1s/step
# Epoch 1/80
# 94/94 [==============================] - 5s 11ms/step - loss: 0.0249
# Epoch 2/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0069
# Epoch 3/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0061
# Epoch 4/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0066
# Epoch 5/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0055
# Epoch 6/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0054
# Epoch 7/80
# 94/94 [==============================] - 2s 19ms/step - loss: 0.0051
# Epoch 8/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0055
# Epoch 9/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0044
# Epoch 10/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0044
# Epoch 11/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0041
# Epoch 12/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0042
# Epoch 13/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0037
# Epoch 14/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0038
# Epoch 15/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0041
# Epoch 16/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0036
# Epoch 17/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0036
# Epoch 18/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0034
# Epoch 19/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0035
# Epoch 20/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0039
# Epoch 21/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0031
# Epoch 22/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0032
# Epoch 23/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0035
# Epoch 24/80
# 94/94 [==============================] - 2s 19ms/step - loss: 0.0033
# Epoch 25/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0031
# Epoch 26/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0032
# Epoch 27/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0032
# Epoch 28/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0032
# Epoch 29/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0031
# Epoch 30/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0029
# Epoch 31/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0032
# Epoch 32/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0029
# Epoch 33/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0031
# Epoch 34/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0033
# Epoch 35/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0032
# Epoch 36/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0032
# Epoch 37/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0031
# Epoch 38/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0030
# Epoch 39/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0031
# Epoch 40/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0032
# Epoch 41/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0030
# Epoch 42/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0033
# Epoch 43/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0030
# Epoch 44/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0030
# Epoch 45/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0031
# Epoch 46/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0028
# Epoch 47/80
# 94/94 [==============================] - 2s 19ms/step - loss: 0.0029
# Epoch 48/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0030
# Epoch 49/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0031
# Epoch 50/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0030
# Epoch 51/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0026
# Epoch 52/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0030
# Epoch 53/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0031
# Epoch 54/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0029
# Epoch 55/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0025
# Epoch 56/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0028
# Epoch 57/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0030
# Epoch 58/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0030
# Epoch 59/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0029
# Epoch 60/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0029
# Epoch 61/80
# 94/94 [==============================] - 2s 20ms/step - loss: 0.0028
# Epoch 62/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0029
# Epoch 63/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0028
# Epoch 64/80
# 94/94 [==============================] - 2s 19ms/step - loss: 0.0027
# Epoch 65/80
# 94/94 [==============================] - 2s 19ms/step - loss: 0.0028
# Epoch 66/80
# 94/94 [==============================] - 2s 19ms/step - loss: 0.0030
# Epoch 67/80
# 94/94 [==============================] - 2s 20ms/step - loss: 0.0030
# Epoch 68/80
# 94/94 [==============================] - 2s 20ms/step - loss: 0.0028
# Epoch 69/80
# 94/94 [==============================] - 2s 21ms/step - loss: 0.0028
# Epoch 70/80
# 94/94 [==============================] - 2s 19ms/step - loss: 0.0030
# Epoch 71/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0028
# Epoch 72/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0027
# Epoch 73/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0029
# Epoch 74/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0028
# Epoch 75/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0026
# Epoch 76/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0027
# Epoch 77/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0026
# Epoch 78/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0029
# Epoch 79/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0028
# Epoch 80/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0028
# 1/1 [==============================] - 1s 785ms/step
# Epoch 1/80
# 94/94 [==============================] - 7s 17ms/step - loss: 0.0230
# Epoch 2/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0079
# Epoch 3/80
# 94/94 [==============================] - 2s 20ms/step - loss: 0.0085
# Epoch 4/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0061
# Epoch 5/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0068
# Epoch 6/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0065
# Epoch 7/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0069
# Epoch 8/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0055
# Epoch 9/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0054
# Epoch 10/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0052
# Epoch 11/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0051
# Epoch 12/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0055
# Epoch 13/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0052
# Epoch 14/80
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0048
# Epoch 15/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0046
# Epoch 16/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0049
# Epoch 17/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0048
# Epoch 18/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0046
# Epoch 19/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0048
# Epoch 20/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0047
# Epoch 21/80
# 94/94 [==============================] - 2s 19ms/step - loss: 0.0039
# Epoch 22/80
# 94/94 [==============================] - 2s 19ms/step - loss: 0.0044
# Epoch 23/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0041
# Epoch 24/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0040
# Epoch 25/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0039
# Epoch 26/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0043
# Epoch 27/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0041
# Epoch 28/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0040
# Epoch 29/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0044
# Epoch 30/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0039
# Epoch 31/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0037
# Epoch 32/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0039
# Epoch 33/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0038
# Epoch 34/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0041
# Epoch 35/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0039
# Epoch 36/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0040
# Epoch 37/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0037
# Epoch 38/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0037
# Epoch 39/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0041
# Epoch 40/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0040
# Epoch 41/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0038
# Epoch 42/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0039
# Epoch 43/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0040
# Epoch 44/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0041
# Epoch 45/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0038
# Epoch 46/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0038
# Epoch 47/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0042
# Epoch 48/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0039
# Epoch 49/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0038
# Epoch 50/80
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0037
# Epoch 51/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0039
# Epoch 52/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0039
# Epoch 53/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0038
# Epoch 54/80
# 94/94 [==============================] - 2s 19ms/step - loss: 0.0037
# Epoch 55/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0038
# Epoch 56/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0039
# Epoch 57/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0037
# Epoch 58/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0036
# Epoch 59/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0037
# Epoch 60/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0037
# Epoch 61/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0037
# Epoch 62/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0039
# Epoch 63/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0037
# Epoch 64/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0038
# Epoch 65/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0035
# Epoch 66/80
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0037
# Epoch 67/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0037
# Epoch 68/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0036
# Epoch 69/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0039
# Epoch 70/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0036
# Epoch 71/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0034
# Epoch 72/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0037
# Epoch 73/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0035
# Epoch 74/80
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0038
# Epoch 75/80
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0036
# Epoch 76/80
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0035
# Epoch 77/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0034
# Epoch 78/80
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0040
# Epoch 79/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0032
# Epoch 80/80
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0039
# 1/1 [==============================] - 1s 769ms/step
# ERROR:root:Error fetching data for FB: {'chart': {'result': None, 'error': {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}}}
