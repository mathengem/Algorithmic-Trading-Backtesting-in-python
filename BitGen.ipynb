# %% [markdown]
# <a href="https://colab.research.google.com/github/mathengem/Algorithmic-Trading-Backtesting-in-python/blob/main/BitGen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

ITERATION_LIMIT = 1000

# initialize the matrix
A = np.array([[10., -1., 2., 0.],
              [-1., 11., -1., 3.],
              [2., -1., 10., -1.],
              [0.0, 3., -1., 8.]])
# initialize the RHS vector
b = np.array([6., 25., -11., 15.])

# prints the system
print("System:")
for i in range(A.shape[0]):
    row = [f"{A[i, j]}*x{j + 1}" for j in range(A.shape[1])]
    print(f'{" + ".join(row)} = {b[i]}')
print()

x = np.zeros_like(b)
for it_count in range(ITERATION_LIMIT):
    if it_count != 0:
        print(f"Iteration {it_count}: {x}")
    x_new = np.zeros_like(x)

    for i in range(A.shape[0]):
        s1 = np.dot(A[i, :i], x[:i])
        s2 = np.dot(A[i, i + 1:], x[i + 1:])
        x_new[i] = (b[i] - s1 - s2) / A[i, i]
        if x_new[i] == x_new[i-1]:
          break

    if np.allclose(x, x_new, atol=1e-10, rtol=0.):
        break

    x = x_new

print("Solution: ")
print(x)
error = np.dot(A, x) - b
print("Error:")
print(error)
# Out:
# System:
# 10.0*x1 + -1.0*x2 + 2.0*x3 + 0.0*x4 = 6.0
# -1.0*x1 + 11.0*x2 + -1.0*x3 + 3.0*x4 = 25.0
# 2.0*x1 + -1.0*x2 + 10.0*x3 + -1.0*x4 = -11.0
# 0.0*x1 + 3.0*x2 + -1.0*x3 + 8.0*x4 = 15.0
#
# Iteration 1: [ 0.6         2.27272727 -1.1         1.875     ]
# Iteration 2: [ 1.04727273  1.71590909 -0.80522727  0.88522727]
# Iteration 3: [ 0.93263636  2.05330579 -1.04934091  1.13088068]
# Iteration 4: [ 1.01519876  1.95369576 -0.96810863  0.97384272]
# Iteration 5: [ 0.9889913   2.01141473 -1.0102859   1.02135051]
# Iteration 6: [ 1.00319865  1.99224126 -0.99452174  0.99443374]
# Iteration 7: [ 0.99812847  2.00230688 -1.00197223  1.00359431]
# Iteration 8: [ 1.00062513  1.9986703  -0.99903558  0.99888839]
# Iteration 9: [ 0.99967415  2.00044767 -1.00036916  1.00061919]
# Iteration 10: [ 1.0001186   1.99976795 -0.99982814  0.99978598]
# Iteration 11: [ 0.99994242  2.00008477 -1.00006833  1.0001085 ]
# Iteration 12: [ 1.00002214  1.99995896 -0.99996916  0.99995967]
# ...

# %%
import numpy as np

ITERATION_LIMIT = 1000

# initialize the matrix
A = np.array(
    [
        [10.0, -1.0, 2.0, 0.0],
        [-1.0, 11.0, -1.0, 3.0],
        [2.0, -1.0, 10.0, -1.0],
        [0.0, 3.0, -1.0, 8.0],
    ]
)
# initialize the RHS vector
b = np.array([6.0, 25.0, -11.0, 15.0])

print("System of equations:")
for i in range(A.shape[0]):
    row = [f"{A[i,j]:3g}*x{j+1}" for j in range(A.shape[1])]
    print("[{0}] = [{1:3g}]".format(" + ".join(row), b[i]))

x = np.zeros_like(b, np.float_)
for it_count in range(1, ITERATION_LIMIT):
    x_new = np.zeros_like(x, dtype=np.float_)
    print(f"Iteration {it_count}: {x}")
    for i in range(A.shape[0]):
        s1 = np.dot(A[i, :i], x_new[:i])
        s2 = np.dot(A[i, i + 1 :], x[i + 1 :])
        x_new[i] = (b[i] - s1 - s2) / A[i, i]
    if np.allclose(x, x_new, rtol=1e-8):
        break
    x = x_new

print(f"Solution: {x}")
error = np.dot(A, x) - b
print(f"Error: {error}")
# Out:
# System of equations:
# [ 10*x1 +  -1*x2 +   2*x3 +   0*x4] = [  6]
# [ -1*x1 +  11*x2 +  -1*x3 +   3*x4] = [ 25]
# [  2*x1 +  -1*x2 +  10*x3 +  -1*x4] = [-11]
# [  0*x1 +   3*x2 +  -1*x3 +   8*x4] = [ 15]
# Iteration 1: [0. 0. 0. 0.]
# Iteration 2: [ 0.6         2.32727273 -0.98727273  0.87886364]
# Iteration 3: [ 1.03018182  2.03693802 -1.0144562   0.98434122]
# Iteration 4: [ 1.00658504  2.00355502 -1.00252738  0.99835095]
# Iteration 5: [ 1.00086098  2.00029825 -1.00030728  0.99984975]
# Iteration 6: [ 1.00009128  2.00002134 -1.00003115  0.9999881 ]
# Iteration 7: [ 1.00000836  2.00000117 -1.00000275  0.99999922]
# Iteration 8: [ 1.00000067  2.00000002 -1.00000021  0.99999996]
# Iteration 9: [ 1.00000004  1.99999999 -1.00000001  1.        ]
# Iteration 10: [ 1.  2. -1.  1.]
# Solution: [ 1.  2. -1.  1.]
# Error: [ 2.06480930e-08 -1.25551054e-08  3.61417563e-11  0.00000000e+00]

# %%
# %matplotlib inline
import matplotlib.pylab as plt

x = [1954]
y = [43]
z = [115792089237316195423570985008687907852837564279074904382605163141518161494336]

#step 1: inicialize to zero
x.append(0)
y.append(0)
z.append(0)

for i in range(1,100):
    xi = (4 - 2*y[i-1]+ z[i-1])/6
#####Start your code here #####
    yi = 0 #Change this line
    zi = 0 #Change this line
#####End of your code here#####
    #Add latest value to history
    x.append(xi)
    y.append(yi)
    z.append(zi)

#Plot History of values
plt.plot(x, label='x')
plt.plot(y, label='y')
plt.plot(z, label='z')
plt.xlabel('Iteration')
plt.ylabel('Value')
plt.legend(loc=1);

# %%
# !pip install base58

# %%
# !sudo apt-get install libssl-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libssl-dev is already the newest version (3.0.2-0ubuntu1.15).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.

# %%
# !sudo apt install openssl
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following packages will be upgraded:
#   openssl
# 1 upgraded, 0 newly installed, 0 to remove and 44 not upgraded.
# Need to get 1,186 kB of archives.
# After this operation, 0 B of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openssl amd64 3.0.2-0ubuntu1.15 [1,186 kB]
# Fetched 1,186 kB in 35s (34.0 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# ...

# %%
# !pip install pycryptodome
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 11.5 MB/s eta 0:00:00
# ...

# %%
# !pip install ecdsa
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.3/149.3 kB 4.4 MB/s eta 0:00:00
# ...

# %%
import hashlib
import base58
from Crypto.Hash import RIPEMD160
from ecdsa import SigningKey, SECP256k1
from datetime import datetime, timedelta

def date_to_unix_epoch(date):
    return int(date.timestamp() * 1000)

def sha256_hash(data):
    return hashlib.sha256(data.encode()).hexdigest()

def generate_private_key(hash_hex):
    return bytes.fromhex(hash_hex)

def generate_public_key(private_key, compressed=True):
    sk = SigningKey.from_string(private_key, curve=SECP256k1)
    vk = sk.verifying_key
    if compressed:
        return b'\x02' + vk.to_string()[:32] if vk.pubkey.point.y() % 2 == 0 else b'\x03' + vk.to_string()[:32]
    else:
        return b'\x04' + vk.to_string()

def sha256(data):
    return hashlib.sha256(data).digest()

def ripemd160(data):
    h = RIPEMD160.new()
    h.update(data)
    return h.digest()

def base58_check_encode(data):
    return base58.b58encode(data).decode()

def derive_address(public_key):
    sha256_pubkey = sha256(public_key)
    ripemd160_pubkey = ripemd160(sha256_pubkey)

    versioned_payload = b'\x00' + ripemd160_pubkey
    checksum = sha256(sha256(versioned_payload))[:4]
    binary_address = versioned_payload + checksum

    return base58_check_encode(binary_address)

# List of target Bitcoin addresses to match
target_addresses = [
    "1NUhcfvRthmvrHf1PAJKe5uEzBGK44ASBD",
    "39CvkBk5JhZJMBUUzpXMtb3qMdNXEcnwcN",
    "174NVbudzKV1jZnZvRzKvauZxnq25NfG4v",
    "14YK4mzJGo5NKkNnmVJeuEAQftLt795Gec",
    "15mkHA8s76bk3Z8ohxF4FSwui1Xs8dGxvH",
    "1BAFWQhH9pNkz3mZDQ1tWrtKkSHVCkc3fV",
    "1FvUkW8thcqG6HP7gAvAjcR52fR7CYodBx",
    "1f1miYFQWTzdLiCBxtHHnNiW7WAWPUccr",
    "1ucXXZQSEf4zny2HRwAQKtVpkLPTUKRtt",
    "167ZWTT8n6s4ya8cGjqNNQjDwDGY31vmHg",
    "1GdtkZzhZTzBssUq6bnE27cz4rv5SJ4sr5",
    "18eY9oWL2mkXCL1VVwPme2NMmAVhX6EfyM"
]

# Loop through dates from January 1, 2010, to December 31, 2018
start_date = datetime(2010, 1, 1)
end_date = datetime(2018, 12, 31)
current_date = start_date

while current_date <= end_date:
    timestamp = date_to_unix_epoch(current_date)

    # Hash the timestamp
    hash_hex = sha256_hash(str(timestamp))

    # Generate private key
    private_key = generate_private_key(hash_hex)

    # Generate public keys (compressed and uncompressed)
    public_key_compressed = generate_public_key(private_key, compressed=True)
    public_key_uncompressed = generate_public_key(private_key, compressed=False)

    # Derive Bitcoin addresses
    btc_address_compressed = derive_address(public_key_compressed)
    btc_address_uncompressed = derive_address(public_key_uncompressed)

    # Print the relevant information for each timestamp
    print(f"Current Date: {current_date}, Timestamp: {timestamp}")
    print(f"SHA-256 Hash: {hash_hex}")
    print(f"Private Key: {private_key.hex()}")
    print(f"Public Key (Compressed): {public_key_compressed.hex()}")
    print(f"Public Key (Uncompressed): {public_key_uncompressed.hex()}")
    print(f"Bitcoin Address (Compressed): {btc_address_compressed}")
    print(f"Bitcoin Address (Uncompressed): {btc_address_uncompressed}")
    print()  # Add a blank line for better readability

    # Check for match
    if btc_address_compressed in target_addresses or btc_address_uncompressed in target_addresses:
        print(f"Match found on date: {current_date.strftime('%Y-%m-%d %H:%M:%S.%f')}")
        print(f"Timestamp: {timestamp}")
        print(f"SHA-256 Hash: {hash_hex}")
        print(f"Hex Private Key: {hash_hex}")
        print(f"Bitcoin Address (Compressed): {btc_address_compressed}")
        print(f"Bitcoin Address (Uncompressed): {btc_address_uncompressed}")
        break

    # Move to the next millisecond
    current_date += timedelta(milliseconds=1)
else:
    print("No match found in the given date range.")
# Out:
# Streaming output truncated to the last 5000 lines.
# Private Key: 5e4e68ec8352082b0ec0e686a1f25bc0df10a69d23a11e19f5f14d7f284a573a
# Public Key (Compressed): 02823bb7241df00261ccde76c0bf33649b9623889276e25deb5c4abb46ffa2f72c
# Public Key (Uncompressed): 04823bb7241df00261ccde76c0bf33649b9623889276e25deb5c4abb46ffa2f72cf2a6cdd7fd26b5af8f998592b30c9eea8eef5a14f3590c2c210f858ae200dcf8
# Bitcoin Address (Compressed): 19bMgbE45jAHo8Y4Wi828ZFNrKqgMiz8pG
# Bitcoin Address (Uncompressed): 15qrAx9iBXhFRhCQWquzfRoFLggbmytUrx
#
# Current Date: 2010-01-01 00:00:02.034000, Timestamp: 1262304002034
# SHA-256 Hash: 3e3806b8cd8fdba177751b8f9766b8047e2cb6494f1bb4b9815bdb8e744c296e
# Private Key: 3e3806b8cd8fdba177751b8f9766b8047e2cb6494f1bb4b9815bdb8e744c296e
# Public Key (Compressed): 0362e6dec8d39831c1a989ed3a0c5e2d0d8bb56d8027b42147e92f51b8aa89b1cf
# ...

# %%
import hashlib
import base58
from Crypto.Hash import RIPEMD160
from ecdsa import SigningKey, SECP256k1
from datetime import datetime, timedelta
import os

def date_to_unix_epoch(date):
    return int(date.timestamp() * 1000)

def sha256_hash(data):
    return hashlib.sha256(data.encode()).hexdigest()

def generate_private_key(hash_hex):
    return bytes.fromhex(hash_hex)

def generate_public_key(private_key, compressed=True):
    sk = SigningKey.from_string(private_key, curve=SECP256k1)
    vk = sk.verifying_key
    if compressed:
        return b'\x02' + vk.to_string()[:32] if vk.pubkey.point.y() % 2 == 0 else b'\x03' + vk.to_string()[:32]
    else:
        return b'\x04' + vk.to_string()

def sha256(data):
    return hashlib.sha256(data).digest()

def ripemd160(data):
    h = RIPEMD160.new()
    h.update(data)
    return h.digest()

def base58_check_encode(data):
    return base58.b58encode(data).decode()

def derive_address(public_key):
    sha256_pubkey = sha256(public_key)
    ripemd160_pubkey = ripemd160(sha256_pubkey)

    versioned_payload = b'\x00' + ripemd160_pubkey
    checksum = sha256(sha256(versioned_payload))[:4]
    binary_address = versioned_payload + checksum

    return base58_check_encode(binary_address)

# List of target Bitcoin addresses to match
target_addresses = [
    "1NUhcfvRthmvrHf1PAJKe5uEzBGK44ASBD",
    "39CvkBk5JhZJMBUUzpXMtb3qMdNXEcnwcN",
    "174NVbudzKV1jZnZvRzKvauZxnq25NfG4v",
    "14YK4mzJGo5NKkNnmVJeuEAQftLt795Gec",
    "15mkHA8s76bk3Z8ohxF4FSwui1Xs8dGxvH",
    "1BAFWQhH9pNkz3mZDQ1tWrtKkSHVCkc3fV",
    "1FvUkW8thcqG6HP7gAvAjcR52fR7CYodBx",
    "1f1miYFQWTzdLiCBxtHHnNiW7WAWPUccr",
    "1ucXXZQSEf4zny2HRwAQKtVpkLPTUKRtt",
    "167ZWTT8n6s4ya8cGjqNNQjDwDGY31vmHg",
    "1GdtkZzhZTzBssUq6bnE27cz4rv5SJ4sr5",
    "18eY9oWL2mkXCL1VVwPme2NMmAVhX6EfyM"
]

# Function to clear the console
def clear_console():
    os.system('cls' if os.name == 'nt' else 'clear')

# Loop through dates from January 1, 2010, to December 31, 2018
start_date = datetime(2010, 1, 1)
end_date = datetime(2018, 12, 31)
current_date = start_date

while current_date <= end_date:
    timestamp = date_to_unix_epoch(current_date)

    # Hash the timestamp
    hash_hex = sha256_hash(str(timestamp))

    # Generate private key
    private_key = generate_private_key(hash_hex)

    # Generate public keys (compressed and uncompressed)
    public_key_compressed = generate_public_key(private_key, compressed=True)
    public_key_uncompressed = generate_public_key(private_key, compressed=False)

    # Derive Bitcoin addresses
    btc_address_compressed = derive_address(public_key_compressed)
    btc_address_uncompressed = derive_address(public_key_uncompressed)

    # Clear the console before printing the new set of information
    clear_console()

    # Print the relevant information for each timestamp
    print(f"Current Date: {current_date}, Timestamp: {timestamp}")
    print(f"SHA-256 Hash: {hash_hex}")
    print(f"Private Key: {private_key.hex()}")
    print(f"Public Key (Compressed): {public_key_compressed.hex()}")
    print(f"Public Key (Uncompressed): {public_key_uncompressed.hex()}")
    print(f"Bitcoin Address (Compressed): {btc_address_compressed}")
    print(f"Bitcoin Address (Uncompressed): {btc_address_uncompressed}")

    # Check for match
    if btc_address_compressed in target_addresses or btc_address_uncompressed in target_addresses:
        print(f"Match found on date: {current_date.strftime('%Y-%m-%d %H:%M:%S.%f')}")
        print(f"Timestamp: {timestamp}")
        print(f"SHA-256 Hash: {hash_hex}")
        print(f"Hex Private Key: {hash_hex}")
        print(f"Bitcoin Address (Compressed): {btc_address_compressed}")
        print(f"Bitcoin Address (Uncompressed): {btc_address_uncompressed}")
        break

    # Move to the next millisecond
    current_date += timedelta(milliseconds=1)
else:
    print("No match found in the given date range.")
# Out:
# Streaming output truncated to the last 5000 lines.
# Bitcoin Address (Compressed): 1E3T6Eh5txt7NXsjnYAXMoo1Dsgkp7yx9Z
# Bitcoin Address (Uncompressed): 17fEwmmdJrH4EiKkNAZVqbJbd4SAp2ihPp
# Current Date: 2010-01-01 00:00:05.003000, Timestamp: 1262304005003
# SHA-256 Hash: a552b006d7a0e6c82f52824e5f1e9e93e2d76afcb94f9c75aa4b96baf65c9663
# Private Key: a552b006d7a0e6c82f52824e5f1e9e93e2d76afcb94f9c75aa4b96baf65c9663
# Public Key (Compressed): 031226df4a82750f9f9a069ff0acbd813365d9a56e82ab9d5c2f96c4c6279a680b
# Public Key (Uncompressed): 041226df4a82750f9f9a069ff0acbd813365d9a56e82ab9d5c2f96c4c6279a680b9c816e06b932b949d61d835d26913d11e71e99e5e6038f8c88152ae4531c4109
# Bitcoin Address (Compressed): 17K7P3d6ULWFrDP7xKfYdb3yQRH5wevuch
# Bitcoin Address (Uncompressed): 1KzbmVQqGriG3tE8BFitzzqWxdvx5wGMHj
# Current Date: 2010-01-01 00:00:05.004000, Timestamp: 1262304005004
# SHA-256 Hash: b6ee0f7552f713412c7acaa2fe48877eccd85800d69093182de9fde121930219
# ...
