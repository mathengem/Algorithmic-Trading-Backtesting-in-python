# %% [markdown]
# <a href="https://colab.research.google.com/github/mathengem/Algorithmic-Trading-Backtesting-in-python/blob/main/BitxoinLib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt install build-essential python3-dev libgmp3-dev pkg-config postgresql postgresql-contrib mariadb-server libpq-dev libmysqlclient-dev pkg-config
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.9ubuntu3).
# pkg-config is already the newest version (0.29.2-1ubuntu3).
# libmysqlclient-dev is already the newest version (8.0.36-0ubuntu0.22.04.1).
# libmysqlclient-dev set to manually installed.
# libpq-dev is already the newest version (14.12-0ubuntu0.22.04.1).
# libpq-dev set to manually installed.
# python3-dev is already the newest version (3.10.6-1~22.04).
# python3-dev set to manually installed.
# The following additional packages will be installed:
#   galera-4 gawk libcgi-fast-perl libcgi-pm-perl libclone-perl libcommon-sense-perl
#   libconfig-inifiles-perl libdbd-mysql-perl libdbi-perl libencode-locale-perl libfcgi-bin
#   libfcgi-perl libfcgi0ldbl libgmp-dev libgmpxx4ldbl libhtml-parser-perl libhtml-tagset-perl
#   libhtml-template-perl libhttp-date-perl libhttp-message-perl libio-html-perl libjson-perl
# ...

# %%
# !git clone https://github.com/1200wd/bitcoinlib.git
# Out:
# Cloning into 'bitcoinlib'...
# remote: Enumerating objects: 21617, done.
# remote: Counting objects: 100% (5349/5349), done.
# remote: Compressing objects: 100% (869/869), done.
# remote: Total 21617 (delta 4564), reused 4870 (delta 4442), pack-reused 16268
# Receiving objects: 100% (21617/21617), 10.43 MiB | 16.56 MiB/s, done.
# Resolving deltas: 100% (16952/16952), done.

# %%
cd bitcoinlib
# Out:
# /content/bitcoinlib

# %%
# !python -m pip install .
# Out:
# Processing /content/bitcoinlib
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 kB 5.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for bitcoinlib: filename=bitcoinlib-0.6.15-py3-none-any.whl size=4235617 sha256=92ee6315690e95b678932ef5f0e42ae2519e71685b0102d06e4cd21562162c30
#   Stored in directory: /tmp/pip-ephem-wheel-cache-tttlm1aj/wheels/5f/6d/49/f1be7df01a53970f9d48ce855ac128d39d9db5529cb7817dc3
# ...

# %%
# !pip install pyqrcode
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 1.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyqrcode: filename=PyQRCode-1.2.1-py3-none-any.whl size=36223 sha256=61fd793e1d16bc43d199138b33d2f66bee7d82b8eb49161da21a0c90d8a35e09
#   Stored in directory: /root/.cache/pip/wheels/34/2d/20/082874e49a32cdcc87ebaf99dd0099fb7774ef30f010dfb6f2
# Successfully built pyqrcode
# ...

# %%
# !python -m unittest
# Out:
# Could not import all modules. Error: No module named 'mysql'
# DATABASE USED: None
# Could not import all modules. Error: No module named 'mysql'
# Could not import all modules. Error: No module named 'mysql'
# .......................................................................................................KEY INFO
#  Network                     bitcoin
#  Compressed                  True
# SECRET EXPONENT
#  Private Key (hex)              02b7bf5358846c0181c8bf009138b97826ba2d62573c6e33c8e363e5877a2ca7
#  Private Key (long)             1229279190570744356239707146913761024289047554395643525774691414993735920807
#  Private Key (wif)              KwJzbbDcb7R5PHW4bVpqP6jCzBqAUio5oxsXGBTtD1C2fx3ZdrGN
# PUBLIC KEY
#  Public Key (hex)            037c2d8c39e4bffaa1569c4b6a7c21c3633ace7361c45db4ad2f2882fceb8abd3d
#  Public Key uncompr. (hex)   047c2d8c39e4bffaa1569c4b6a7c21c3633ace7361c45db4ad2f2882fceb8abd3d9273dff0d7aa516a3a69f019ff6b259a0f38f19510727320844033142cfd2f91
# ...

# %%
# !clw new -w mywallet
# Out:
# Command Line Wallet - BitcoinLib 0.6.15
#
# CREATE wallet 'mywallet' (bitcoin network)
# Passphrase: diet acid else know truly lend tag inform bleak hurdle lottery avoid
# Please write down on paper and backup. With this key you can restore your wallet and all keys
#
# Type 'yes' if you understood and wrote down your key: yes
# Wallet info for mywallet
# === WALLET ===
#  ID                             4
#  Name                           mywallet
#  Owner
#  Scheme                         bip32
#  Multisig                       False
#  Witness type                   segwit
#  Main network                   bitcoin
#  Latest update                  None
#
# = Wallet Master Key =
#  ID                             47
#  Private                        True
#  Depth                          0
#
# - NETWORK: bitcoin -
# - - Keys
#    52 m/84'/0'/0'/0/0              bc1q0aun5gucddyq05wvjgzjy5wkewawd0yfdm3rf9    address index 0                        0.00000000 ₿
#
# ...

# %%
# !clw -w mywallet -r
# Out:
# Command Line Wallet - BitcoinLib 0.6.15
#
# Receive address: bc1q0aun5gucddyq05wvjgzjy5wkewawd0yfdm3rf9
